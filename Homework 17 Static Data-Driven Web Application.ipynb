# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("Anthony Bourdain Travels.csv")

# %%
df.head()
# Out:
#      Air Date           Airdate              City   Country  Day  \
# 0  01/08/2002   January 8, 2002             Tokyo     Japan    8
# 1  01/12/2002  January 12, 2002             Atami     Japan   12
# 2   1/15/2002  January 15, 2002  Ho Chi Minh City   Vietnam   15
# 3   1/15/2002  January 15, 2002      Mekong River   Vietnam   15
# 4   1/22/2002  January 22, 2002        Phnom Penh  Cambodia   22
#
#                                          Description  Episode   Latitude  \
# 0  Join Tony in Tokyo as he learns about the Japa...        1  35.689487
# 1  Rural Japan: Tony decides to look for a more r...        2  35.096276
# 2  Travel with Tony Bourdain to Ho Chi Minh City ...        3  10.823099
# 3  On the river, Tony drinks a lot of Mekong moon...        4  15.933589
# 4  With a friend along for the ride, Tony travels...        5  11.556374
#
#     Longitude  Month  Month.1  Order Region  Season           Show  \
# ...

# %%
conn = sqlite3.connect("bourdain.db")

# %%
df.to_sql('bourdain', conn)
# Out:
# /Users/angelawang/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py:2127: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
pd.read_sql("SELECT * FROM bourdain", conn)
# Out:
#      index    Air Date            Airdate                     City  \
# 0        0  01/08/2002    January 8, 2002                    Tokyo
# 1        1  01/12/2002   January 12, 2002                    Atami
# 2        2   1/15/2002   January 15, 2002         Ho Chi Minh City
# 3        3   1/15/2002   January 15, 2002             Mekong River
# 4        4   1/22/2002   January 22, 2002               Phnom Penh
# 5        5   1/29/2002   January 29, 2002               Battambang
# 6        6   1/29/2002   January 29, 2002                   Pailin
# 7        7   1/29/2002   January 29, 2002                    Tokyo
# 8        8  02/05/2002   February 5, 2002                    Porto
# 9        9  02/12/2002  February 12, 2002            San Sebastian
# 10      10   2/19/2002  February 19, 2002                 Arcachon
# 11      11   2/26/2002  February 26, 2002                 Amarante
# 12      12  03/05/2002      March 5, 2002                  Rissani
# ...
